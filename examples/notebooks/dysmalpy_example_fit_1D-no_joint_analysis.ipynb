# %% [markdown]
# # Example `Dysmalpy` 1D fitting #

# %% [markdown]
# **Includes the following components:**
#  - Disk + Bulge
#  - NFW halo
#  - Constant velocity dispersion

# %% [markdown]
# #### First import modules ####

# %%
from __future__ import (absolute_import, division, print_function,
                        unicode_literals)

from dysmalpy import galaxy
from dysmalpy import models
from dysmalpy import fitting
from dysmalpy import instrument
from dysmalpy import data_classes
from dysmalpy import parameters
from dysmalpy import plotting
from dysmalpy import aperture_classes

import os
import copy

import numpy as np
import astropy.units as u
import astropy.io.fits as fits

# %% [markdown]
# ##### Setup notebook #####

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

from IPython.core.display import Image

# %%
import logging
logger = logging.getLogger('DysmalPy')
logger.setLevel(logging.INFO)

# %% [markdown]
# #### Set data, output paths ####

# %%
# Data directory
data_dir = '/Users/sedona/data/dysmalpy_example_data/'
#'/YOUR/DATA/PATH/'

# Where to save output files
#outdir  = './output_1D/'
outdir = '/Users/sedona/data/dysmalpy_test_examples/JUPYTER_OUTPUT_1D/'

# %% [markdown]
# -------------------

# %% [markdown]
# ##### Set function to tie scale height relative to effective radius #####

# %%
def tie_sigz_reff(model_set):
 
    reff = model_set.components['disk+bulge'].r_eff_disk.value
    invq = model_set.components['disk+bulge'].invq_disk
    sigz = 2.0*reff/invq/2.35482

    return sigz

# %% [markdown]
# ##### Set function to tie Mvirial to $f_{DM}(R_e)$

# %%
def tie_lmvirial_NFW(model_set):
    comp_halo = model_set.components.__getitem__('halo')
    comp_baryons = model_set.components.__getitem__('disk+bulge')
    r_fdm = model_set.components['disk+bulge'].r_eff_disk.value
    mvirial = comp_halo.calc_mvirial_from_fdm(comp_baryons, r_fdm, 
                    adiabatic_contract=model_set.kinematic_options.adiabatic_contract)
    return mvirial

# %% [markdown]
# - Also see **fitting_wrappers.utils_io** for more tied functions

# %% [markdown]
# ----------

# %% [markdown]
# ## Initialize galaxy, model set, instrument ##

# %%
gal = galaxy.Galaxy(z=1.613, name='GS4_43501')
mod_set = models.ModelSet()
inst = instrument.Instrument()

# %% [markdown]
# ### Baryonic component: Combined Disk+Bulge ###

# %%
total_mass = 11.0    # M_sun
bt = 0.3             # Bulge-Total ratio
r_eff_disk = 5.0     # kpc
n_disk = 1.0
invq_disk = 5.0
r_eff_bulge = 1.0    # kpc
n_bulge = 4.0
invq_bulge = 1.0
noord_flat = True    # Switch for applying Noordermeer flattening

# Fix components
bary_fixed = {'total_mass': False,
              'r_eff_disk': False, #True,
              'n_disk': True,
              'r_eff_bulge': True,
              'n_bulge': True,
              'bt': True}

# Set bounds
bary_bounds = {'total_mass': (10, 13),
               'r_eff_disk': (1.0, 30.0),
               'n_disk': (1, 8),
               'r_eff_bulge': (1, 5),
               'n_bulge': (1, 8),
               'bt': (0, 1)}

bary = models.DiskBulge(total_mass=total_mass, bt=bt,
                        r_eff_disk=r_eff_disk, n_disk=n_disk,
                        invq_disk=invq_disk,
                        r_eff_bulge=r_eff_bulge, n_bulge=n_bulge,
                        invq_bulge=invq_bulge,
                        noord_flat=noord_flat,
                        name='disk+bulge',
                        fixed=bary_fixed, bounds=bary_bounds)

bary.r_eff_disk.prior = parameters.BoundedGaussianPrior(center=5.0, stddev=1.0)

# %% [markdown]
# ### Halo component ###

# %%
mvirial = 12.0
conc = 5.0
fdm = 0.5

halo_fixed = {'mvirial': False,
              'conc': True, 
              'fdm':  False}
# Mvirial will be tied -- so must set 'fixed=False' for Mvirial...

halo_bounds = {'mvirial': (10, 13),
               'conc': (1, 20),
               'fdm': (0, 1)}

halo = models.NFW(mvirial=mvirial, conc=conc, fdm=fdm, z=gal.z,
                  fixed=halo_fixed, bounds=halo_bounds, name='halo')


halo.mvirial.tied = tie_lmvirial_NFW

# %% [markdown]
# ### Dispersion profile ###

# %%
sigma0 = 39.   # km/s
disp_fixed = {'sigma0': False}
disp_bounds = {'sigma0': (5, 300)}

disp_prof = models.DispersionConst(sigma0=sigma0, fixed=disp_fixed,
                                          bounds=disp_bounds, name='dispprof')

# %% [markdown]
# ### z-height profile ###

# %%
sigmaz = 0.9   # kpc
zheight_fixed = {'sigmaz': False}

zheight_prof = models.ZHeightGauss(sigmaz=sigmaz, name='zheightgaus',
                                   fixed=zheight_fixed)
zheight_prof.sigmaz.tied = tie_sigz_reff

# %% [markdown]
# ### Geometry ###

# %%
inc = 62.     # degrees
pa = 142.     # degrees, blue-shifted side CCW from north
xshift = 0    # pixels from center
yshift = 0    # pixels from center

geom_fixed = {'inc': True,
              'pa': True,
              'xshift': True,
              'yshift': True}

geom_bounds = {'inc': (0, 90),
               'pa': (90, 180),
               'xshift': (0, 4),
               'yshift': (-10, -4)}

geom = models.Geometry(inc=inc, pa=pa, xshift=xshift, yshift=yshift,
                       fixed=geom_fixed, bounds=geom_bounds, name='geom')

# %% [markdown]
# ## Add all model components to ModelSet ##

# %%
# Add all of the model components to the ModelSet
mod_set.add_component(bary, light=True)
mod_set.add_component(halo)
mod_set.add_component(disp_prof)
mod_set.add_component(zheight_prof)
mod_set.add_component(geom)

# %% [markdown]
# ### Set kinematic options for calculating velocity profile ###

# %%
mod_set.kinematic_options.adiabatic_contract = False
mod_set.kinematic_options.pressure_support = True

# %% [markdown]
# ### Set up the instrument ###

# %%
beamsize = 0.55*u.arcsec                 # FWHM of beam
sig_inst = 45*u.km/u.s                   # Instrumental spectral resolution

beam = instrument.GaussianBeam(major=beamsize)
lsf = instrument.LSF(sig_inst)

inst.beam = beam
inst.lsf = lsf
inst.pixscale = 0.125*u.arcsec           # arcsec/pixel
inst.fov = [33, 33]                      # (nx, ny) pixels
inst.spec_type = 'velocity'              # 'velocity' or 'wavelength'
inst.spec_step = 10*u.km/u.s             # Spectral step
inst.spec_start = -1000*u.km/u.s         # Starting value of spectrum
inst.nspec = 201                         # Number of spectral pixels

# Set the beam kernel so it doesn't have to be calculated every step
inst.set_beam_kernel()
inst.set_lsf_kernel()

# %% [markdown]
# ## Add the model set, instrument to the Galaxy ##

# %%
gal.model = mod_set
gal.instrument = inst

# %% [markdown]
# ## Load data ##

# %% [markdown]
# * Load the data from file:
#   - *1D velocity, dispersion profiles and error*
#   - *A mask can be loaded / created as well*
#
# * Put data in `Data1D` class
#
# * Add data to Galaxy object

# %%
f_data_1d = data_dir+'GS4_43501.obs_prof.txt'
dat_arr = np.loadtxt(f_data_1d)
gs4_r = dat_arr[:,0]
gs4_vel = dat_arr[:,1]
gs4_disp = dat_arr[:,3]
err_vel = dat_arr[:,2]
err_disp = dat_arr[:,4]
inst_corr = True                  # Flag for if the measured dispersion has been
                                  # corrected for instrumental resolution
    
# Put data in Data1D data class: 
#    ** specifies slit width, slit PA as well **
data1d = data_classes.Data1D(r=gs4_r, velocity=gs4_vel,
                                  vel_disp=gs4_disp, vel_err=err_vel,
                                  vel_disp_err=err_disp, slit_width=beamsize.value,
                                  slit_pa=pa, inst_corr=inst_corr, 
                                  filename_velocity=f_data_1d)

# Add data to Galaxy object:
gal.data = data1d

# %% [markdown]
# #### Setup apertures:

# %%
# Setup apertures: circular apertures placed on the cube for GS4_43501.

profile1d_type = 'circ_ap_cube'    # Extraction in circular apertures placed on the cube

aperture_radius = 0.5 * gal.instrument.beam.major.value

moment_calc  = False    # 1D data was extracted using Gaussian fits

gal.data.apertures = aperture_classes.setup_aperture_types(gal=gal, 
                profile1d_type=profile1d_type, 
                aperture_radius=aperture_radius, 
                from_data=True, 
                partial_weight=True,
                moment=moment_calc)

# Add profile1d_type to data:
gal.data.profile1d_type = profile1d_type

# %% [markdown]
# -----------------

# %% [markdown]
# # MPFIT Fitting #

# %% [markdown]
# ## MPFIT fitting parameters: ##

# %%
# Options passed to MPFIT:
maxiter = 200

# Other options:
do_plotting = True       # Plot bestfit, corner, trace or not
oversample = 1           # Factor by which to oversample model (eg, subpixels)
fitdispersion = True     # Fit dispersion profile in addition to velocity

outdir_mpfit = outdir+'MPFIT/'

# Choose plot filetype:
plot_type = 'png'

# %% [markdown]
# ## Run `Dysmalpy` fitting: MPFIT ##

# %%
mpfit_results = fitting.fit_mpfit(gal, oversample=oversample,
                                        fitdispersion=fitdispersion,
                                        profile1d_type=gal.data.profile1d_type,
                                        maxiter=maxiter,
                                        do_plotting=do_plotting,
                                        outdir=outdir_mpfit,
                                        plot_type=plot_type)
# Out:
# INFO:DysmalPy:Making path=/Users/sedona/data/dysmalpy_test_examples/JUPYTER_OUTPUT_1D/MPFIT/
# INFO:DysmalPy:*************************************
# INFO:DysmalPy: Fitting: GS4_43501 using MPFIT
# INFO:DysmalPy:    velocity file: /Users/sedona/data/dysmalpy_example_data/GS4_43501.obs_prof.txt
# INFO:DysmalPy:
# mvirial_tied: <function tie_lmvirial_NFW at 0x1a1a122950>
# INFO:DysmalPy:nSubpixels: 1
# INFO:DysmalPy:
# MPFIT Fitting:
# Start: 2020-10-18 00:15:04.748657
#
# INFO:DysmalPy:Iter 1  CHI-SQUARE = 1335.146297  DOF = 32
#    disk+bulge:total_mass = 11
#    disk+bulge:r_eff_disk = 5
#    halo:fdm = 0.5
#    dispprof:sigma0 = 39
#
# INFO:DysmalPy:Iter 2  CHI-SQUARE = 92.45642108  DOF = 32
#    disk+bulge:total_mass = 10.7376182
#    disk+bulge:r_eff_disk = 3.193570965
#    halo:fdm = 0.3338865341
#    dispprof:sigma0 = 45.13124411
#
# INFO:DysmalPy:Iter 3  CHI-SQUARE = 60.37634696  DOF = 32
#    disk+bulge:total_mass = 10.68463857
#    disk+bulge:r_eff_disk = 2.961076539
#    halo:fdm = 0.2934130551
#    dispprof:sigma0 = 39.38225665
#
# INFO:DysmalPy:Iter 4  CHI-SQUARE = 60.25036744  DOF = 32
#    disk+bulge:total_mass = 10.68127324
#    disk+bulge:r_eff_disk = 2.911168825
#    halo:fdm = 0.2855317629
#    dispprof:sigma0 = 38.8506286
#
# INFO:DysmalPy:Iter 5  CHI-SQUARE = 60.24735415  DOF = 32
#    disk+bulge:total_mass = 10.68027716
#    disk+bulge:r_eff_disk = 2.893606027
#    halo:fdm = 0.2836676081
#    dispprof:sigma0 = 38.7206634
#
# INFO:DysmalPy:Iter 6  CHI-SQUARE = 60.24725236  DOF = 32
#    disk+bulge:total_mass = 10.68012641
#    disk+bulge:r_eff_disk = 2.890693483
#    halo:fdm = 0.2833408088
#    dispprof:sigma0 = 38.69957878
#
# INFO:DysmalPy:Iter 7  CHI-SQUARE = 60.24724529  DOF = 32
#    disk+bulge:total_mass = 10.6800759
#    disk+bulge:r_eff_disk = 2.889839958
#    halo:fdm = 0.2832542781
#    dispprof:sigma0 = 38.6937079
#
# INFO:DysmalPy:Iter 8  CHI-SQUARE = 60.24724515  DOF = 32
#    disk+bulge:total_mass = 10.68007046
#    disk+bulge:r_eff_disk = 2.889730614
#    halo:fdm = 0.2832420621
#    dispprof:sigma0 = 38.69295567
#
# INFO:DysmalPy:Iter 9  CHI-SQUARE = 60.24724513  DOF = 32
#    disk+bulge:total_mass = 10.68006842
#    disk+bulge:r_eff_disk = 2.889696231
#    halo:fdm = 0.283238588
#    dispprof:sigma0 = 38.69271992
#
# INFO:DysmalPy:
# End: 2020-10-18 00:15:22.488882
#
# ******************
# Time= 17.74 (sec),   0:17.74 (m:s)
# MPFIT Status = 1
# MPFIT Error/Warning Message = None
# ******************

# %% [markdown]
# ## Examine MPFIT results ##

# %%
# Look at best-fit:
filepath = outdir_mpfit+"mpfit_best_fit.{}".format(plot_type)
Image(filename=filepath, width=600, height=570)

# %% [markdown]
# #### Reload the galaxy, results files:

# %%
f_galmodel =       outdir_mpfit + 'galaxy_model.pickle'
f_mpfit_results =  outdir_mpfit + 'mpfit_results.pickle'

gal, mpfit_results = fitting.reload_all_fitting_mpfit(filename_galmodel=f_galmodel, 
                            filename_results=f_mpfit_results)

# %% [markdown]
# #### Plot the best-fit results:

# %%
mpfit_results.plot_results(gal, fitdispersion=fitdispersion, 
                              oversample=oversample, 
                              f_plot_bestfit=None)

# %% [markdown]
# ### Print results report:

# %%
# Print report
print(mpfit_results.results_report(gal=gal))
# Out:
# ###############################
#  Fitting for GS4_43501
#
# Date: 2020-10-18 00:15:25.268736
#
# Datafile: /Users/sedona/data/dysmalpy_example_data/GS4_43501.obs_prof.txt
#
# Fitting method: MPFIT
#
# profile1d_type: circ_ap_cube
# moment_calc: False
# partial_weight: True
# pressure_support_type: 1
#
# ###############################
#  Fitting results
# -----------
#  disk+bulge
#     total_mass       10.6801  +/-   0.0401
#     r_eff_disk        2.8897  +/-   0.3326
#
#     n_disk            1.0000  [FIXED]
#     r_eff_bulge       1.0000  [FIXED]
#     n_bulge           4.0000  [FIXED]
#     bt                0.3000  [FIXED]
# -----------
#  halo
#     fdm               0.2832  +/-   0.0478
#
#     mvirial          12.4925  [TIED]
#     conc              5.0000  [FIXED]
# -----------
#  dispprof
#     sigma0           38.6927  +/-   4.3020
# -----------
#  zheightgaus
#     sigmaz            0.4909  [TIED]
# -----------
#  geom
#     inc              62.0000  [FIXED]
#     pa              142.0000  [FIXED]
#     xshift            0.0000  [FIXED]
#     yshift            0.0000  [FIXED]
#     vel_shift         0.0000  [FIXED]
#
# -----------
# Adiabatic contraction: False
#
# -----------
# Red. chisq: 1.8827

# %% [markdown]
# ### Or save results report to file:

# %%
# Save report to file:
f_mpfit_report = outdir_mpfit + 'mpfit_fit_report.txt'
mpfit_results.results_report(gal=gal, filename=f_mpfit_report)

# %% [markdown]
# -----------------

# %% [markdown]
# # MCMC Fitting #

# %% [markdown]
# ##### Get a clean copy of model, instrument

# %%
gal.model = copy.deepcopy(mod_set)
gal.instrument = copy.deepcopy(inst)

# %% [markdown]
# ### MCMC fitting parameters ###

# %% [markdown]
# Set parameters for fitting:
#    - Passing options to `emcee`
#    - Other calculation options

# %%
# Options passed to emcee
nwalkers = 1000
ncpus = 4
scale_param_a = 3
nburn = 50
nsteps = 200
minaf = None
maxaf = None
neff = 10

# nwalkers = 500
# ncpus = 4
# scale_param_a = 3
# nburn = 50
# nsteps = 50
# minaf = None
# maxaf = None
# neff = 10

# # SHORT TEST:
# nwalkers = 20
# ncpus = 4
# scale_param_a = 3
# nburn = 2
# nsteps = 5
# minaf = None
# maxaf = None
# neff = 10

# Other options
do_plotting = True       # Plot bestfit, corner, trace or not
oversample = 1           # Factor by which to oversample model (eg, subpixels)
fitdispersion = True     # Fit dispersion profile in addition to velocity

blob_name = 'mvirial'    # Also save 'blob' values of Mvirial, calculated at every chain step

outdir_mcmc = outdir + 'MCMC/'

# Choose plot filetype:
plot_type = 'png'

# %% [markdown]
# -------

# %% [markdown]
# ## Run `Dysmalpy` fitting: MCMC ##

# %%
gal.model.components['zheightgaus'].sigmaz.tied
# Out:
# <function __main__.tie_sigz_reff(model_set)>

# %%
mcmc_results = fitting.fit(gal, nWalkers=nwalkers, nCPUs=ncpus,
                               scale_param_a=scale_param_a, nBurn=nburn,
                               nSteps=nsteps, minAF=minaf, maxAF=maxaf,
                               nEff=neff, do_plotting=do_plotting,
                               oversample=oversample, outdir=outdir_mcmc,
                               fitdispersion=fitdispersion,
                               profile1d_type=gal.data.profile1d_type,
                               blob_name=blob_name, 
                               plot_type=plot_type)
# Out:
# INFO:DysmalPy:Making path=/Users/sedona/data/dysmalpy_test_examples/JUPYTER_OUTPUT_1D/MCMC/
# INFO:DysmalPy:*************************************
# INFO:DysmalPy: Fitting: GS4_43501 with MCMC
# INFO:DysmalPy:    velocity file: /Users/sedona/data/dysmalpy_example_data/GS4_43501.obs_prof.txt
# INFO:DysmalPy:
# nCPUs: 4
# INFO:DysmalPy:nWalkers: 1000
# INFO:DysmalPy:lnlike: red_chisq=False
# INFO:DysmalPy:lnlike: oversampled_chisq=True
# INFO:DysmalPy:
# blobs: mvirial
# INFO:DysmalPy:
# mvirial_tied: <function tie_lmvirial_NFW at 0x1a1a122950>
# INFO:DysmalPy:nSubpixels: 1
# INFO:DysmalPy:
# Burn-in:
# Start: 2020-10-18 00:15:25.453280
#
# INFO:DysmalPy: k=0, time.time=2020-10-18 00:15:25.454317, a_frac=nan
# INFO:DysmalPy: k=1, time.time=2020-10-18 00:20:09.333325, a_frac=0.295
# INFO:DysmalPy: k=2, time.time=2020-10-18 00:21:52.703392, a_frac=0.301
# INFO:DysmalPy: k=3, time.time=2020-10-18 00:23:40.479206, a_frac=0.29966666666666664
# INFO:DysmalPy: k=4, time.time=2020-10-18 00:25:30.563967, a_frac=0.29375
# INFO:DysmalPy: k=5, time.time=2020-10-18 00:27:26.209782, a_frac=0.28520000000000006
# INFO:DysmalPy: k=6, time.time=2020-10-18 00:29:21.536889, a_frac=0.2803333333333333
# INFO:DysmalPy: k=7, time.time=2020-10-18 00:31:19.562963, a_frac=0.2808571428571428
# INFO:DysmalPy: k=8, time.time=2020-10-18 00:33:14.294476, a_frac=0.279625
# INFO:DysmalPy: k=9, time.time=2020-10-18 00:35:14.901299, a_frac=0.27911111111111114
# INFO:DysmalPy: k=10, time.time=2020-10-18 00:37:19.575118, a_frac=0.2806
# INFO:DysmalPy: k=11, time.time=2020-10-18 00:39:18.224447, a_frac=0.2799090909090909
# INFO:DysmalPy: k=12, time.time=2020-10-18 00:41:20.407235, a_frac=0.2786666666666667
# INFO:DysmalPy: k=13, time.time=2020-10-18 00:43:27.765115, a_frac=0.27946153846153843
# INFO:DysmalPy: k=14, time.time=2020-10-18 00:45:35.712913, a_frac=0.27764285714285714
# INFO:DysmalPy: k=15, time.time=2020-10-18 00:47:48.327242, a_frac=0.2786
# INFO:DysmalPy: k=16, time.time=2020-10-18 00:49:56.266576, a_frac=0.2778125
# INFO:DysmalPy: k=17, time.time=2020-10-18 00:52:10.265059, a_frac=0.27670588235294113
# INFO:DysmalPy: k=18, time.time=2020-10-18 00:54:22.126955, a_frac=0.278
# INFO:DysmalPy: k=19, time.time=2020-10-18 00:56:35.900324, a_frac=0.27863157894736845
# INFO:DysmalPy: k=20, time.time=2020-10-18 00:58:47.544181, a_frac=0.27875
# INFO:DysmalPy: k=21, time.time=2020-10-18 01:00:59.881762, a_frac=0.2783333333333333
# INFO:DysmalPy: k=22, time.time=2020-10-18 01:03:16.772821, a_frac=0.27868181818181814
# INFO:DysmalPy: k=23, time.time=2020-10-18 01:05:29.254975, a_frac=0.2777826086956522
# INFO:DysmalPy: k=24, time.time=2020-10-18 01:07:48.691375, a_frac=0.2776666666666666
# INFO:DysmalPy: k=25, time.time=2020-10-18 01:10:06.679409, a_frac=0.27740000000000004
# INFO:DysmalPy: k=26, time.time=2020-10-18 01:12:26.168236, a_frac=0.27803846153846157
# INFO:DysmalPy: k=27, time.time=2020-10-18 01:14:43.326598, a_frac=0.2779259259259259
# INFO:DysmalPy: k=28, time.time=2020-10-18 01:17:05.406739, a_frac=0.27821428571428575
# INFO:DysmalPy: k=29, time.time=2020-10-18 01:19:27.244841, a_frac=0.2787241379310345
# INFO:DysmalPy: k=30, time.time=2020-10-18 01:21:48.773703, a_frac=0.27876666666666666
# INFO:DysmalPy: k=31, time.time=2020-10-18 01:24:16.764766, a_frac=0.27858064516129033
# INFO:DysmalPy: k=32, time.time=2020-10-18 01:26:42.768841, a_frac=0.279125
# INFO:DysmalPy: k=33, time.time=2020-10-18 01:29:06.941235, a_frac=0.27918181818181814
# INFO:DysmalPy: k=34, time.time=2020-10-18 01:31:33.705172, a_frac=0.2801470588235294
# INFO:DysmalPy: k=35, time.time=2020-10-18 01:34:01.070691, a_frac=0.2803142857142857
# INFO:DysmalPy: k=36, time.time=2020-10-18 01:36:32.909402, a_frac=0.28075
# INFO:DysmalPy: k=37, time.time=2020-10-18 01:39:01.991636, a_frac=0.2813783783783784
# INFO:DysmalPy: k=38, time.time=2020-10-18 01:41:32.271388, a_frac=0.28207894736842104
# INFO:DysmalPy: k=39, time.time=2020-10-18 01:44:00.195765, a_frac=0.2817692307692307
# INFO:DysmalPy: k=40, time.time=2020-10-18 01:46:34.846019, a_frac=0.28269999999999995
# INFO:DysmalPy: k=41, time.time=2020-10-18 01:49:09.039510, a_frac=0.2832682926829268
# INFO:DysmalPy: k=42, time.time=2020-10-18 01:51:43.144354, a_frac=0.28357142857142853
# INFO:DysmalPy: k=43, time.time=2020-10-18 01:54:20.660823, a_frac=0.28416279069767436
# INFO:DysmalPy: k=44, time.time=2020-10-18 01:56:56.361172, a_frac=0.2850454545454545
# INFO:DysmalPy: k=45, time.time=2020-10-18 01:59:33.665737, a_frac=0.28557777777777776
# INFO:DysmalPy: k=46, time.time=2020-10-18 02:02:08.447836, a_frac=0.2867391304347826
# INFO:DysmalPy: k=47, time.time=2020-10-18 02:04:44.939798, a_frac=0.287936170212766
# INFO:DysmalPy: k=48, time.time=2020-10-18 02:07:22.412236, a_frac=0.2882291666666667
# INFO:DysmalPy: k=49, time.time=2020-10-18 02:10:01.775188, a_frac=0.28967346938775507
# INFO:DysmalPy:
# End: 2020-10-18 02:12:42.860152
#
# ******************
# nCPU, nParam, nWalker, nBurn = 4, 4, 1000, 50
# Scale param a= 3
# Time= 7037.41 (sec), 117:17.41 (m:s)
# Mean acceptance fraction: 0.291
# Ideal acceptance frac: 0.2 - 0.5
# Autocorr est: Undefined, chain did not converge
# ******************
# INFO:DysmalPy:
# #################
# acorr time undefined -> can't check convergence
# #################
#
# INFO:DysmalPy:
# Ensemble sampling:
# Start: 2020-10-18 02:12:48.553552
#
# INFO:DysmalPy:ii=0, a_frac=0.311 time.time()=2020-10-18 02:15:24.794974
# INFO:DysmalPy: 0: Chain too short for acor to run
# INFO:DysmalPy:ii=1, a_frac=0.3225 time.time()=2020-10-18 02:18:01.612820
# INFO:DysmalPy: 1: Chain too short for acor to run
# INFO:DysmalPy:ii=2, a_frac=0.3293333333333333 time.time()=2020-10-18 02:20:41.758559
# INFO:DysmalPy: 2: Chain too short for acor to run
# INFO:DysmalPy:ii=3, a_frac=0.33575 time.time()=2020-10-18 02:23:21.475372
# INFO:DysmalPy: 3: Chain too short for acor to run
# INFO:DysmalPy:ii=4, a_frac=0.3408 time.time()=2020-10-18 02:26:03.082095
# INFO:DysmalPy: 4: Chain too short for acor to run
# INFO:DysmalPy:ii=5, a_frac=0.3406666666666666 time.time()=2020-10-18 02:28:41.488491
# INFO:DysmalPy: 5: Chain too short for acor to run
# INFO:DysmalPy:ii=6, a_frac=0.3365714285714286 time.time()=2020-10-18 02:31:21.793422
# INFO:DysmalPy: 6: Chain too short for acor to run
# INFO:DysmalPy:ii=7, a_frac=0.3365 time.time()=2020-10-18 02:34:02.439607
# INFO:DysmalPy: 7: Chain too short for acor to run
# INFO:DysmalPy:ii=8, a_frac=0.3368888888888889 time.time()=2020-10-18 02:36:41.716042
# INFO:DysmalPy: 8: Chain too short for acor to run
# INFO:DysmalPy:ii=9, a_frac=0.3403 time.time()=2020-10-18 02:39:19.417225
# INFO:DysmalPy: 9: Chain too short for acor to run
# INFO:DysmalPy:ii=10, a_frac=0.3437272727272727 time.time()=2020-10-18 02:42:00.660451
# INFO:DysmalPy: 10: Chain too short for acor to run
# INFO:DysmalPy:ii=11, a_frac=0.34241666666666665 time.time()=2020-10-18 02:44:40.840534
# INFO:DysmalPy: 11: Chain too short for acor to run
# INFO:DysmalPy:ii=12, a_frac=0.34369230769230774 time.time()=2020-10-18 02:47:17.831362
# INFO:DysmalPy: 12: Chain too short for acor to run
# INFO:DysmalPy:ii=13, a_frac=0.34342857142857136 time.time()=2020-10-18 02:49:58.575889
# INFO:DysmalPy: 13: Chain too short for acor to run
# INFO:DysmalPy:ii=14, a_frac=0.34440000000000004 time.time()=2020-10-18 02:52:35.178192
# INFO:DysmalPy: 14: Chain too short for acor to run
# INFO:DysmalPy:ii=15, a_frac=0.34525 time.time()=2020-10-18 02:55:14.808537
# INFO:DysmalPy: 15: Chain too short for acor to run
# INFO:DysmalPy:ii=16, a_frac=0.3457647058823529 time.time()=2020-10-18 02:57:54.009582
# INFO:DysmalPy: 16: Chain too short for acor to run
# INFO:DysmalPy:ii=17, a_frac=0.34627777777777785 time.time()=2020-10-18 03:00:34.156463
# INFO:DysmalPy: 17: Chain too short for acor to run
# INFO:DysmalPy:ii=18, a_frac=0.34657894736842104 time.time()=2020-10-18 03:03:16.978086
# INFO:DysmalPy: 18: Chain too short for acor to run
# INFO:DysmalPy:ii=19, a_frac=0.34605 time.time()=2020-10-18 03:05:54.843744
# INFO:DysmalPy: 19: Chain too short for acor to run
# INFO:DysmalPy:ii=20, a_frac=0.34790476190476194 time.time()=2020-10-18 03:08:35.909838
# INFO:DysmalPy: 20: Chain too short for acor to run
# INFO:DysmalPy:ii=21, a_frac=0.3499545454545455 time.time()=2020-10-18 03:11:20.043592
# INFO:DysmalPy: 21: Chain too short for acor to run
# INFO:DysmalPy:ii=22, a_frac=0.35060869565217395 time.time()=2020-10-18 03:13:58.113294
# INFO:DysmalPy: 22: Chain too short for acor to run
# INFO:DysmalPy:ii=23, a_frac=0.3514583333333334 time.time()=2020-10-18 03:16:38.209103
# INFO:DysmalPy: 23: Chain too short for acor to run
# INFO:DysmalPy:ii=24, a_frac=0.35296000000000005 time.time()=2020-10-18 03:19:21.325714
# INFO:DysmalPy: 24: Chain too short for acor to run
# INFO:DysmalPy:ii=25, a_frac=0.3530384615384615 time.time()=2020-10-18 03:22:02.166321
# INFO:DysmalPy: 25: Chain too short for acor to run
# INFO:DysmalPy:ii=26, a_frac=0.35377777777777775 time.time()=2020-10-18 03:24:41.442487
# INFO:DysmalPy: 26: Chain too short for acor to run
# INFO:DysmalPy:ii=27, a_frac=0.3545 time.time()=2020-10-18 03:27:23.402747
# INFO:DysmalPy: 27: Chain too short for acor to run
# INFO:DysmalPy:ii=28, a_frac=0.35555172413793107 time.time()=2020-10-18 03:30:05.172553
# INFO:DysmalPy: 28: Chain too short for acor to run
# INFO:DysmalPy:ii=29, a_frac=0.3554666666666667 time.time()=2020-10-18 03:32:42.358898
# INFO:DysmalPy: 29: Chain too short for acor to run
# INFO:DysmalPy:ii=30, a_frac=0.3560322580645161 time.time()=2020-10-18 03:35:25.290640
# INFO:DysmalPy: 30: Chain too short for acor to run
# INFO:DysmalPy:ii=31, a_frac=0.35621875 time.time()=2020-10-18 03:38:07.266504
# INFO:DysmalPy: 31: Chain too short for acor to run
# INFO:DysmalPy:ii=32, a_frac=0.35721212121212115 time.time()=2020-10-18 03:40:45.875545
# INFO:DysmalPy: 32: Chain too short for acor to run
# INFO:DysmalPy:ii=33, a_frac=0.35661764705882354 time.time()=2020-10-18 03:43:24.887622
# INFO:DysmalPy: 33: Chain too short for acor to run
# INFO:DysmalPy:ii=34, a_frac=0.35651428571428573 time.time()=2020-10-18 03:46:06.940715
# INFO:DysmalPy: 34: Chain too short for acor to run
# INFO:DysmalPy:ii=35, a_frac=0.3561111111111111 time.time()=2020-10-18 03:48:51.624601
# INFO:DysmalPy: 35: Chain too short for acor to run
# INFO:DysmalPy:ii=36, a_frac=0.35637837837837844 time.time()=2020-10-18 03:51:31.704145
# INFO:DysmalPy: 36: Chain too short for acor to run
# INFO:DysmalPy:ii=37, a_frac=0.3564473684210526 time.time()=2020-10-18 03:54:10.034548
# INFO:DysmalPy: 37: Chain too short for acor to run
# INFO:DysmalPy:ii=38, a_frac=0.3565897435897436 time.time()=2020-10-18 03:56:51.069759
# INFO:DysmalPy: 38: Chain too short for acor to run
# INFO:DysmalPy:ii=39, a_frac=0.356225 time.time()=2020-10-18 03:59:32.512577
# INFO:DysmalPy: 39: Chain too short for acor to run
# INFO:DysmalPy:ii=40, a_frac=0.35663414634146345 time.time()=2020-10-18 04:02:13.283506
# INFO:DysmalPy: 40: Chain too short for acor to run
# INFO:DysmalPy:ii=41, a_frac=0.3567619047619048 time.time()=2020-10-18 04:04:53.497601
# INFO:DysmalPy: 41: Chain too short for acor to run
# INFO:DysmalPy:ii=42, a_frac=0.35604651162790696 time.time()=2020-10-18 04:07:30.902943
# INFO:DysmalPy: 42: Chain too short for acor to run
# INFO:DysmalPy:ii=43, a_frac=0.35615909090909087 time.time()=2020-10-18 04:10:07.738630
# INFO:DysmalPy: 43: Chain too short for acor to run
# INFO:DysmalPy:ii=44, a_frac=0.35644444444444445 time.time()=2020-10-18 04:12:49.493346
# INFO:DysmalPy: 44: Chain too short for acor to run
# INFO:DysmalPy:ii=45, a_frac=0.3563478260869565 time.time()=2020-10-18 04:15:28.803364
# INFO:DysmalPy: 45: Chain too short for acor to run
# INFO:DysmalPy:ii=46, a_frac=0.35634042553191486 time.time()=2020-10-18 04:18:10.390231
# INFO:DysmalPy: 46: Chain too short for acor to run
# INFO:DysmalPy:ii=47, a_frac=0.35633333333333334 time.time()=2020-10-18 04:20:50.426948
# INFO:DysmalPy: 47: Chain too short for acor to run
# INFO:DysmalPy:ii=48, a_frac=0.3564897959183673 time.time()=2020-10-18 04:23:29.875592
# INFO:DysmalPy: 48: Chain too short for acor to run
# INFO:DysmalPy:ii=49, a_frac=0.35658000000000006 time.time()=2020-10-18 04:26:07.938841
# INFO:DysmalPy: 49: Chain too short for acor to run
# INFO:DysmalPy:ii=50, a_frac=0.35645098039215684 time.time()=2020-10-18 04:28:48.588549
# INFO:DysmalPy: 50: Chain too short for acor to run
# INFO:DysmalPy:ii=51, a_frac=0.3568461538461538 time.time()=2020-10-18 04:31:29.913264
# INFO:DysmalPy: 51: Chain too short for acor to run
# INFO:DysmalPy:ii=52, a_frac=0.35709433962264153 time.time()=2020-10-18 04:34:08.675604
# INFO:DysmalPy: 52: Chain too short for acor to run
# INFO:DysmalPy:ii=53, a_frac=0.35722222222222216 time.time()=2020-10-18 04:36:46.568898
# INFO:DysmalPy: 53: Chain too short for acor to run
# INFO:DysmalPy:ii=54, a_frac=0.3572181818181818 time.time()=2020-10-18 04:39:25.147052
# INFO:DysmalPy: 54: Chain too short for acor to run
# INFO:DysmalPy:ii=55, a_frac=0.357375 time.time()=2020-10-18 04:42:04.967399
# INFO:DysmalPy: 55: Chain too short for acor to run
# INFO:DysmalPy:ii=56, a_frac=0.35752631578947364 time.time()=2020-10-18 04:44:45.164667
# INFO:DysmalPy: 56: Chain too short for acor to run
# INFO:DysmalPy:ii=57, a_frac=0.3574827586206897 time.time()=2020-10-18 04:47:24.986391
# INFO:DysmalPy: 57: Chain too short for acor to run
# INFO:DysmalPy:ii=58, a_frac=0.35793220338983045 time.time()=2020-10-18 04:50:06.765802
# INFO:DysmalPy: 58: Chain too short for acor to run
# INFO:DysmalPy:ii=59, a_frac=0.35768333333333335 time.time()=2020-10-18 04:52:44.716282
# INFO:DysmalPy: 59: Chain too short for acor to run
# INFO:DysmalPy:ii=60, a_frac=0.35793442622950816 time.time()=2020-10-18 04:55:25.794859
# INFO:DysmalPy: 60: Chain too short for acor to run
# INFO:DysmalPy:ii=61, a_frac=0.3581451612903226 time.time()=2020-10-18 04:58:04.190014
# INFO:DysmalPy: 61: Chain too short for acor to run
# INFO:DysmalPy:ii=62, a_frac=0.3582539682539682 time.time()=2020-10-18 05:01:00.509098
# INFO:DysmalPy: 62: Chain too short for acor to run
# INFO:DysmalPy:ii=63, a_frac=0.35821875 time.time()=2020-10-18 05:05:19.119326
# INFO:DysmalPy: 63: Chain too short for acor to run
# INFO:DysmalPy:ii=64, a_frac=0.35803076923076926 time.time()=2020-10-18 05:09:42.231104
# INFO:DysmalPy: 64: Chain too short for acor to run
# INFO:DysmalPy:ii=65, a_frac=0.35824242424242425 time.time()=2020-10-18 05:14:00.596808
# INFO:DysmalPy: 65: Chain too short for acor to run
# INFO:DysmalPy:ii=66, a_frac=0.35846268656716423 time.time()=2020-10-18 05:18:21.792230
# INFO:DysmalPy: 66: Chain too short for acor to run
# INFO:DysmalPy:ii=67, a_frac=0.3587058823529412 time.time()=2020-10-18 05:22:56.294138
# INFO:DysmalPy: 67: Chain too short for acor to run
# INFO:DysmalPy:ii=68, a_frac=0.35844927536231885 time.time()=2020-10-18 05:27:32.405888
# INFO:DysmalPy: 68: Chain too short for acor to run
# INFO:DysmalPy:ii=69, a_frac=0.35821428571428565 time.time()=2020-10-18 05:32:20.026196
# INFO:DysmalPy: 69: Chain too short for acor to run
# INFO:DysmalPy:ii=70, a_frac=0.35829577464788737 time.time()=2020-10-18 05:36:51.081306
# INFO:DysmalPy: 70: Chain too short for acor to run
# INFO:DysmalPy:ii=71, a_frac=0.35801388888888885 time.time()=2020-10-18 05:41:23.563136
# INFO:DysmalPy: 71: Chain too short for acor to run
# INFO:DysmalPy:ii=72, a_frac=0.3581369863013698 time.time()=2020-10-18 05:45:59.174539
# INFO:DysmalPy: 72: Chain too short for acor to run
# INFO:DysmalPy:ii=73, a_frac=0.35821621621621624 time.time()=2020-10-18 05:50:30.472426
# INFO:DysmalPy: 73: Chain too short for acor to run
# INFO:DysmalPy:ii=74, a_frac=0.358 time.time()=2020-10-18 05:55:02.033566
# INFO:DysmalPy: 74: Chain too short for acor to run
# INFO:DysmalPy:ii=75, a_frac=0.3579473684210527 time.time()=2020-10-18 05:59:36.584741
# INFO:DysmalPy: 75: Chain too short for acor to run
# INFO:DysmalPy:ii=76, a_frac=0.35814285714285715 time.time()=2020-10-18 06:04:11.178904
# INFO:DysmalPy: 76: Chain too short for acor to run
# INFO:DysmalPy:ii=77, a_frac=0.35796153846153844 time.time()=2020-10-18 06:08:42.201871
# INFO:DysmalPy: 77: Chain too short for acor to run
# INFO:DysmalPy:ii=78, a_frac=0.35801265822784806 time.time()=2020-10-18 06:12:57.552530
# INFO:DysmalPy: 78: Chain too short for acor to run
# INFO:DysmalPy:ii=79, a_frac=0.35795 time.time()=2020-10-18 06:17:30.223627
# INFO:DysmalPy: 79: Chain too short for acor to run
# INFO:DysmalPy:ii=80, a_frac=0.35814814814814816 time.time()=2020-10-18 06:22:01.947929
# INFO:DysmalPy: 80: Chain too short for acor to run
# INFO:DysmalPy:ii=81, a_frac=0.3582560975609756 time.time()=2020-10-18 06:25:56.139668
# INFO:DysmalPy: 81: Chain too short for acor to run
# INFO:DysmalPy:ii=82, a_frac=0.3583734939759036 time.time()=2020-10-18 06:30:36.188667
# INFO:DysmalPy: 82: Chain too short for acor to run
# INFO:DysmalPy:ii=83, a_frac=0.3587023809523809 time.time()=2020-10-18 06:35:05.440126
# INFO:DysmalPy: 83: Chain too short for acor to run
# INFO:DysmalPy:ii=84, a_frac=0.35876470588235293 time.time()=2020-10-18 06:39:33.008000
# INFO:DysmalPy: 84: Chain too short for acor to run
# INFO:DysmalPy:ii=85, a_frac=0.3589418604651162 time.time()=2020-10-18 06:43:51.310187
# INFO:DysmalPy: 85: Chain too short for acor to run
# INFO:DysmalPy:ii=86, a_frac=0.35874712643678164 time.time()=2020-10-18 06:48:20.328695
# INFO:DysmalPy: 86: Chain too short for acor to run
# INFO:DysmalPy:ii=87, a_frac=0.35867045454545454 time.time()=2020-10-18 06:52:50.806707
# INFO:DysmalPy: 87: Chain too short for acor to run
# INFO:DysmalPy:ii=88, a_frac=0.3588988764044943 time.time()=2020-10-18 06:57:11.992178
# INFO:DysmalPy: 88: Chain too short for acor to run
# INFO:DysmalPy:ii=89, a_frac=0.35906666666666665 time.time()=2020-10-18 07:01:44.770116
# INFO:DysmalPy: 89: Chain too short for acor to run
# INFO:DysmalPy:ii=90, a_frac=0.35923076923076924 time.time()=2020-10-18 07:06:17.690201
# INFO:DysmalPy: 90: Chain too short for acor to run
# INFO:DysmalPy:ii=91, a_frac=0.35930434782608694 time.time()=2020-10-18 07:10:30.217923
# INFO:DysmalPy: 91: Chain too short for acor to run
# INFO:DysmalPy:ii=92, a_frac=0.35936559139784946 time.time()=2020-10-18 07:13:55.964192
# INFO:DysmalPy: 92: Chain too short for acor to run
# INFO:DysmalPy:ii=93, a_frac=0.35962765957446813 time.time()=2020-10-18 07:18:32.004902
# INFO:DysmalPy: 93: Chain too short for acor to run
# INFO:DysmalPy:ii=94, a_frac=0.3594421052631579 time.time()=2020-10-18 07:23:04.027209
# INFO:DysmalPy: 94: Chain too short for acor to run
# INFO:DysmalPy:ii=95, a_frac=0.35932291666666677 time.time()=2020-10-18 07:27:10.796725
# INFO:DysmalPy: 95: Chain too short for acor to run
# INFO:DysmalPy:ii=96, a_frac=0.3592371134020618 time.time()=2020-10-18 07:31:24.366229
# INFO:DysmalPy: 96: Chain too short for acor to run
# INFO:DysmalPy:ii=97, a_frac=0.3588673469387754 time.time()=2020-10-18 07:35:59.589244
# INFO:DysmalPy: 97: Chain too short for acor to run
# INFO:DysmalPy:ii=98, a_frac=0.3586464646464646 time.time()=2020-10-18 07:40:32.097923
# INFO:DysmalPy: 98: Chain too short for acor to run
# INFO:DysmalPy:ii=99, a_frac=0.35863999999999996 time.time()=2020-10-18 07:44:47.650376
# INFO:DysmalPy: 99: Chain too short for acor to run
# INFO:DysmalPy:ii=100, a_frac=0.3584851485148515 time.time()=2020-10-18 07:49:20.315448
# INFO:DysmalPy: 100: Chain too short for acor to run
# INFO:DysmalPy:ii=101, a_frac=0.3582941176470588 time.time()=2020-10-18 07:53:53.035411
# INFO:DysmalPy: 101: Chain too short for acor to run
# INFO:DysmalPy:ii=102, a_frac=0.3580485436893204 time.time()=2020-10-18 07:58:12.706074
# INFO:DysmalPy: 102: Chain too short for acor to run
# INFO:DysmalPy:ii=103, a_frac=0.3578173076923077 time.time()=2020-10-18 08:02:09.267797
# INFO:DysmalPy: 103: Chain too short for acor to run
# INFO:DysmalPy:ii=104, a_frac=0.35774285714285714 time.time()=2020-10-18 08:06:40.533936
# INFO:DysmalPy: 104: Chain too short for acor to run
# INFO:DysmalPy:ii=105, a_frac=0.3577547169811321 time.time()=2020-10-18 08:11:15.221660
# INFO:DysmalPy: 105: Chain too short for acor to run
# INFO:DysmalPy:ii=106, a_frac=0.3578317757009346 time.time()=2020-10-18 08:15:44.664511
# INFO:DysmalPy: 106: Chain too short for acor to run
# INFO:DysmalPy:ii=107, a_frac=0.35783333333333334 time.time()=2020-10-18 08:19:31.886539
# INFO:DysmalPy: 107: Chain too short for acor to run
# INFO:DysmalPy:ii=108, a_frac=0.35781651376146795 time.time()=2020-10-18 08:24:04.914540
# INFO:DysmalPy: 108: Chain too short for acor to run
# INFO:DysmalPy:ii=109, a_frac=0.35768181818181816 time.time()=2020-10-18 08:28:37.621604
# INFO:DysmalPy: 109: Chain too short for acor to run
# INFO:DysmalPy:ii=110, a_frac=0.3575495495495495 time.time()=2020-10-18 08:33:11.890477
# INFO:DysmalPy: 110: Chain too short for acor to run
# INFO:DysmalPy:ii=111, a_frac=0.3574821428571429 time.time()=2020-10-18 08:36:35.138123
# INFO:DysmalPy: 111: Chain too short for acor to run
# INFO:DysmalPy:ii=112, a_frac=0.35753097345132745 time.time()=2020-10-18 08:41:04.912354
# INFO:DysmalPy: 112: Chain too short for acor to run
# INFO:DysmalPy:ii=113, a_frac=0.35736842105263156 time.time()=2020-10-18 08:45:40.269347
# INFO:DysmalPy: 113: Chain too short for acor to run
# INFO:DysmalPy:ii=114, a_frac=0.3572173913043479 time.time()=2020-10-18 08:50:13.078156
# INFO:DysmalPy: 114: Chain too short for acor to run
# INFO:DysmalPy:ii=115, a_frac=0.35723275862068965 time.time()=2020-10-18 08:54:19.182915
# INFO:DysmalPy: 115: Chain too short for acor to run
# INFO:DysmalPy:ii=116, a_frac=0.3571367521367521 time.time()=2020-10-18 08:58:23.573752
# INFO:DysmalPy: 116: Chain too short for acor to run
# INFO:DysmalPy:ii=117, a_frac=0.35691525423728815 time.time()=2020-10-18 09:02:48.808029
# INFO:DysmalPy: 117: Chain too short for acor to run
# INFO:DysmalPy:ii=118, a_frac=0.3568151260504202 time.time()=2020-10-18 09:07:16.413338
# INFO:DysmalPy: 118: Chain too short for acor to run
# INFO:DysmalPy:ii=119, a_frac=0.356875 time.time()=2020-10-18 09:11:43.698243
# INFO:DysmalPy: 119: Chain too short for acor to run
# INFO:DysmalPy:ii=120, a_frac=0.35687603305785126 time.time()=2020-10-18 09:15:35.449575
# INFO:DysmalPy: 120: Chain too short for acor to run
# INFO:DysmalPy:ii=121, a_frac=0.35677868852459016 time.time()=2020-10-18 09:20:03.512784
# INFO:DysmalPy: 121: Chain too short for acor to run
# INFO:DysmalPy:ii=122, a_frac=0.35680487804878047 time.time()=2020-10-18 09:24:31.054804
# INFO:DysmalPy: 122: Chain too short for acor to run
# INFO:DysmalPy:ii=123, a_frac=0.35675 time.time()=2020-10-18 09:29:05.597535
# INFO:DysmalPy: 123: Chain too short for acor to run
# INFO:DysmalPy:ii=124, a_frac=0.35658400000000007 time.time()=2020-10-18 09:32:45.129149
# INFO:DysmalPy: 124: Chain too short for acor to run
# INFO:DysmalPy:ii=125, a_frac=0.3567619047619048 time.time()=2020-10-18 09:37:12.669769
# INFO:DysmalPy: 125: Chain too short for acor to run
# INFO:DysmalPy:ii=126, a_frac=0.356732283464567 time.time()=2020-10-18 09:41:44.333115
# INFO:DysmalPy: 126: Chain too short for acor to run
# INFO:DysmalPy:ii=127, a_frac=0.356765625 time.time()=2020-10-18 09:46:15.015282
# INFO:DysmalPy: 127: Chain too short for acor to run
# INFO:DysmalPy:ii=128, a_frac=0.3566821705426356 time.time()=2020-10-18 09:50:20.423991
# INFO:DysmalPy: 128: Chain too short for acor to run
# INFO:DysmalPy:ii=129, a_frac=0.3565846153846154 time.time()=2020-10-18 09:54:38.289282
# INFO:DysmalPy: 129: Chain too short for acor to run
# INFO:DysmalPy:ii=130, a_frac=0.3566106870229008 time.time()=2020-10-18 09:59:08.494103
# INFO:DysmalPy: 130: Chain too short for acor to run
# INFO:DysmalPy:ii=131, a_frac=0.35674242424242425 time.time()=2020-10-18 10:03:36.979317
# INFO:DysmalPy: 131: Chain too short for acor to run
# INFO:DysmalPy:ii=132, a_frac=0.3568796992481203 time.time()=2020-10-18 10:08:09.733398
# INFO:DysmalPy: 132: Chain too short for acor to run
# INFO:DysmalPy:ii=133, a_frac=0.3568731343283582 time.time()=2020-10-18 10:12:09.731598
# INFO:DysmalPy: 133: Chain too short for acor to run
# INFO:DysmalPy:ii=134, a_frac=0.357 time.time()=2020-10-18 10:16:43.360028
# INFO:DysmalPy: 134: Chain too short for acor to run
# INFO:DysmalPy:ii=135, a_frac=0.3570882352941177 time.time()=2020-10-18 10:21:13.797348
# INFO:DysmalPy: 135: Chain too short for acor to run
# INFO:DysmalPy:ii=136, a_frac=0.356970802919708 time.time()=2020-10-18 10:25:43.749073
# INFO:DysmalPy: 136: Chain too short for acor to run
# INFO:DysmalPy:ii=137, a_frac=0.3569347826086956 time.time()=2020-10-18 10:29:40.115138
# INFO:DysmalPy: 137: Chain too short for acor to run
# INFO:DysmalPy:ii=138, a_frac=0.35702877697841723 time.time()=2020-10-18 10:34:11.013253
# INFO:DysmalPy: 138: Chain too short for acor to run
# INFO:DysmalPy:ii=139, a_frac=0.3570357142857143 time.time()=2020-10-18 10:38:40.434727
# INFO:DysmalPy: 139: Chain too short for acor to run
# INFO:DysmalPy:ii=140, a_frac=0.35706382978723405 time.time()=2020-10-18 10:43:16.348303
# INFO:DysmalPy: 140: Chain too short for acor to run
# INFO:DysmalPy:ii=141, a_frac=0.35714084507042254 time.time()=2020-10-18 10:47:24.560967
# INFO:DysmalPy: 141: Chain too short for acor to run
# INFO:DysmalPy:ii=142, a_frac=0.35725174825174827 time.time()=2020-10-18 10:51:41.389188
# INFO:DysmalPy: 142: Chain too short for acor to run
# INFO:DysmalPy:ii=143, a_frac=0.35725694444444445 time.time()=2020-10-18 10:56:12.505014
# INFO:DysmalPy: 143: Chain too short for acor to run
# INFO:DysmalPy:ii=144, a_frac=0.357048275862069 time.time()=2020-10-18 11:00:45.703184
# INFO:DysmalPy: 144: Chain too short for acor to run
# INFO:DysmalPy:ii=145, a_frac=0.3571712328767123 time.time()=2020-10-18 11:05:17.206457
# INFO:DysmalPy: 145: Chain too short for acor to run
# INFO:DysmalPy:ii=146, a_frac=0.3571292517006802 time.time()=2020-10-18 11:09:10.360474
# INFO:DysmalPy: 146: Chain too short for acor to run
# INFO:DysmalPy:ii=147, a_frac=0.3571554054054054 time.time()=2020-10-18 11:13:15.414929
# INFO:DysmalPy: 147: Chain too short for acor to run
# INFO:DysmalPy:ii=148, a_frac=0.35718791946308726 time.time()=2020-10-18 11:17:51.415588
# INFO:DysmalPy: 148: Chain too short for acor to run
# INFO:DysmalPy:ii=149, a_frac=0.35712666666666665 time.time()=2020-10-18 11:22:20.166785
# INFO:DysmalPy: 149: Chain too short for acor to run
# INFO:DysmalPy:ii=150, a_frac=0.35705298013245035 time.time()=2020-10-18 11:26:56.052365
# INFO:DysmalPy: 150: Chain too short for acor to run
# INFO:DysmalPy:ii=151, a_frac=0.3569407894736842 time.time()=2020-10-18 11:31:21.023996
# INFO:DysmalPy: 151: Chain too short for acor to run
# INFO:DysmalPy:ii=152, a_frac=0.3569607843137255 time.time()=2020-10-18 11:35:49.813068
# INFO:DysmalPy: 152: Chain too short for acor to run
# INFO:DysmalPy:ii=153, a_frac=0.35691558441558435 time.time()=2020-10-18 11:40:21.793723
# INFO:DysmalPy: 153: Chain too short for acor to run
# INFO:DysmalPy:ii=154, a_frac=0.35701935483870967 time.time()=2020-10-18 11:44:53.561327
# INFO:DysmalPy: 154: Chain too short for acor to run
# INFO:DysmalPy:ii=155, a_frac=0.35705128205128206 time.time()=2020-10-18 11:49:14.089581
# INFO:DysmalPy: 155: Chain too short for acor to run
# INFO:DysmalPy:ii=156, a_frac=0.35700636942675157 time.time()=2020-10-18 11:53:21.740183
# INFO:DysmalPy: 156: Chain too short for acor to run
# INFO:DysmalPy:ii=157, a_frac=0.3571455696202532 time.time()=2020-10-18 11:57:55.001331
# INFO:DysmalPy: 157: Chain too short for acor to run
# INFO:DysmalPy:ii=158, a_frac=0.3572704402515724 time.time()=2020-10-18 12:02:27.107514
# INFO:DysmalPy: 158: Chain too short for acor to run
# INFO:DysmalPy:ii=159, a_frac=0.35736874999999996 time.time()=2020-10-18 12:07:02.572984
# INFO:DysmalPy: 159: Chain too short for acor to run
# INFO:DysmalPy:ii=160, a_frac=0.3573478260869565 time.time()=2020-10-18 12:11:23.063878
# INFO:DysmalPy: 160: Chain too short for acor to run
# INFO:DysmalPy:ii=161, a_frac=0.35727777777777775 time.time()=2020-10-18 12:16:12.603076
# INFO:DysmalPy: 161: Chain too short for acor to run
# INFO:DysmalPy:ii=162, a_frac=0.3573865030674847 time.time()=2020-10-18 12:20:44.189241
# INFO:DysmalPy: 162: Chain too short for acor to run
# INFO:DysmalPy:ii=163, a_frac=0.35740243902439023 time.time()=2020-10-18 12:25:17.586312
# INFO:DysmalPy: 163: Chain too short for acor to run
# INFO:DysmalPy:ii=164, a_frac=0.3574909090909091 time.time()=2020-10-18 12:29:52.370539
# INFO:DysmalPy: 164: Chain too short for acor to run
# INFO:DysmalPy:ii=165, a_frac=0.3575722891566265 time.time()=2020-10-18 12:33:38.528554
# INFO:DysmalPy: 165: Chain too short for acor to run
# INFO:DysmalPy:ii=166, a_frac=0.35764071856287427 time.time()=2020-10-18 12:38:10.804118
# INFO:DysmalPy: 166: Chain too short for acor to run
# INFO:DysmalPy:ii=167, a_frac=0.35773214285714283 time.time()=2020-10-18 12:42:44.324371
# INFO:DysmalPy: 167: Chain too short for acor to run
# INFO:DysmalPy:ii=168, a_frac=0.35775739644970417 time.time()=2020-10-18 12:47:18.569476
# INFO:DysmalPy: 168: Chain too short for acor to run
# INFO:DysmalPy:ii=169, a_frac=0.3577117647058824 time.time()=2020-10-18 12:51:43.038331
# INFO:DysmalPy: 169: Chain too short for acor to run
# INFO:DysmalPy:ii=170, a_frac=0.357766081871345 time.time()=2020-10-18 12:55:49.056320
# INFO:DysmalPy: 170: Chain too short for acor to run
# INFO:DysmalPy:ii=171, a_frac=0.3578546511627907 time.time()=2020-10-18 13:00:25.123236
# INFO:DysmalPy: 171: Chain too short for acor to run
# INFO:DysmalPy:ii=172, a_frac=0.35783236994219647 time.time()=2020-10-18 13:05:00.374530
# INFO:DysmalPy: 172: Chain too short for acor to run
# INFO:DysmalPy:ii=173, a_frac=0.35794827586206895 time.time()=2020-10-18 13:09:34.771309
# INFO:DysmalPy: 173: Chain too short for acor to run
# INFO:DysmalPy:ii=174, a_frac=0.3580114285714286 time.time()=2020-10-18 13:13:46.640740
# INFO:DysmalPy: 174: Chain too short for acor to run
# INFO:DysmalPy:ii=175, a_frac=0.35802840909090905 time.time()=2020-10-18 13:18:19.460887
# INFO:DysmalPy: 175: Chain too short for acor to run
# INFO:DysmalPy:ii=176, a_frac=0.3580960451977401 time.time()=2020-10-18 13:22:59.037880
# INFO:DysmalPy: 176: Chain too short for acor to run
# INFO:DysmalPy:ii=177, a_frac=0.3582303370786517 time.time()=2020-10-18 13:27:40.639480
# INFO:DysmalPy: 177: Chain too short for acor to run
# INFO:DysmalPy:ii=178, a_frac=0.3582178770949721 time.time()=2020-10-18 13:32:11.024077
# INFO:DysmalPy: 178: Chain too short for acor to run
# INFO:DysmalPy:ii=179, a_frac=0.35839444444444446 time.time()=2020-10-18 13:36:15.510675
# INFO:DysmalPy: 179: Chain too short for acor to run
# INFO:DysmalPy:ii=180, a_frac=0.35841436464088394 time.time()=2020-10-18 13:40:43.444559
# INFO:DysmalPy: 180: Chain too short for acor to run
# INFO:DysmalPy:ii=181, a_frac=0.35844505494505496 time.time()=2020-10-18 13:45:13.866125
# INFO:DysmalPy: 181: Chain too short for acor to run
# INFO:DysmalPy:ii=182, a_frac=0.3585136612021858 time.time()=2020-10-18 13:49:45.597044
# INFO:DysmalPy: 182: Chain too short for acor to run
# INFO:DysmalPy:ii=183, a_frac=0.3585 time.time()=2020-10-18 13:54:16.686018
# INFO:DysmalPy: 183: Chain too short for acor to run
# INFO:DysmalPy:ii=184, a_frac=0.3585081081081081 time.time()=2020-10-18 13:58:19.515987
# INFO:DysmalPy: 184: Chain too short for acor to run
# INFO:DysmalPy:ii=185, a_frac=0.358505376344086 time.time()=2020-10-18 14:02:54.730103
# INFO:DysmalPy: 185: Chain too short for acor to run
# INFO:DysmalPy:ii=186, a_frac=0.35867379679144384 time.time()=2020-10-18 14:07:25.581908
# INFO:DysmalPy: 186: Chain too short for acor to run
# INFO:DysmalPy:ii=187, a_frac=0.35873936170212767 time.time()=2020-10-18 14:12:01.447734
# INFO:DysmalPy: 187: Chain too short for acor to run
# INFO:DysmalPy:ii=188, a_frac=0.3587566137566138 time.time()=2020-10-18 14:16:36.579524
# INFO:DysmalPy: 188: Chain too short for acor to run
# INFO:DysmalPy:ii=189, a_frac=0.3589578947368421 time.time()=2020-10-18 14:20:34.067154
# INFO:DysmalPy: 189: Chain too short for acor to run
# INFO:DysmalPy:ii=190, a_frac=0.3590471204188482 time.time()=2020-10-18 14:24:56.009433
# INFO:DysmalPy: 190: Chain too short for acor to run
# INFO:DysmalPy:ii=191, a_frac=0.3590520833333334 time.time()=2020-10-18 14:29:32.279615
# INFO:DysmalPy: 191: Chain too short for acor to run
# INFO:DysmalPy:ii=192, a_frac=0.3592176165803109 time.time()=2020-10-18 14:34:06.709331
# INFO:DysmalPy: 192: Chain too short for acor to run
# INFO:DysmalPy:ii=193, a_frac=0.3592319587628866 time.time()=2020-10-18 14:38:42.030766
# INFO:DysmalPy: 193: Chain too short for acor to run
# INFO:DysmalPy:ii=194, a_frac=0.3593128205128205 time.time()=2020-10-18 14:42:52.494967
# INFO:DysmalPy: 194: Chain too short for acor to run
# INFO:DysmalPy:ii=195, a_frac=0.3592755102040816 time.time()=2020-10-18 14:47:24.488294
# INFO:DysmalPy: 195: Chain too short for acor to run
# INFO:DysmalPy:ii=196, a_frac=0.3593857868020304 time.time()=2020-10-18 14:51:59.528494
# INFO:DysmalPy: 196: Chain too short for acor to run
# INFO:DysmalPy:ii=197, a_frac=0.3593989898989899 time.time()=2020-10-18 14:56:29.045093
# INFO:DysmalPy: 197: Chain too short for acor to run
# INFO:DysmalPy:ii=198, a_frac=0.3593115577889447 time.time()=2020-10-18 15:01:01.159469
# INFO:DysmalPy: 198: Chain too short for acor to run
# INFO:DysmalPy:ii=199, a_frac=0.359355 time.time()=2020-10-18 15:05:12.090310
# INFO:DysmalPy: 199: Chain too short for acor to run
# INFO:DysmalPy:Finished 200 steps
#
# INFO:DysmalPy:
# End: 2020-10-18 15:05:12.094299
#
# ******************
# nCPU, nParam, nWalker, nSteps = 4, 4, 1000, 200
# Scale param a= 3
# Time= 46343.54 (sec), 772:23.54 (m:s)
# Mean acceptance fraction: 0.359
# Ideal acceptance frac: 0.2 - 0.5
# Autocorr est: Undefined, chain not converged
# ******************
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours

# %% [markdown]
# ## Examine MCMC results ##

# %%
# Look at trace:
filepath = outdir_mcmc+"mcmc_trace.{}".format(plot_type)
Image(filepath, width=600, height=400)

# %%
# Look at best-fit:
filepath = outdir_mcmc+"mcmc_best_fit.{}".format(plot_type)
Image(filepath, width=600, height=570)

# %%
# Look at corner:
filepath = outdir_mcmc+"mcmc_param_corner.{}".format(plot_type)
Image(filepath, width=570, height=620)

# %% [markdown]
# ---------

# %% [markdown]
# ## Load and examine results: ##

# %% [markdown]
# Helpful for:
#   - replotting
#   - reanalyzing chain (eg, jointly constraining some posteriors)
#   - ...

# %% [markdown]
# #### Reload the galaxy, results files:

# %%
f_galmodel =      outdir_mcmc + 'galaxy_model.pickle'
f_mcmc_results =  outdir_mcmc + 'mcmc_results.pickle'

gal, mcmc_results = fitting.reload_all_fitting(filename_galmodel=f_galmodel, 
                            filename_mcmc_results=f_mcmc_results)

# %% [markdown]
# #### If necessary, also reload the sampler chain:

# %%
f_sampler =  outdir_mcmc + 'mcmc_sampler.pickle'
mcmc_results.reload_sampler(filename=f_sampler)

# %% [markdown]
# #### Plot the best-fit results:

# %%
mcmc_results.plot_results(gal, fitdispersion=fitdispersion, 
                          oversample=oversample, 
                          f_plot_param_corner=None, 
                          f_plot_bestfit=None, f_plot_trace=None)
# Out:
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours

# %% [markdown]
# ### Print results report:

# %%
# Print report
print(mcmc_results.results_report(gal=gal))
# Out:
# ###############################
#  Fitting for GS4_43501
#
# Date: 2020-10-18 15:06:07.429692
#
# Datafile: /Users/sedona/data/dysmalpy_example_data/GS4_43501.obs_prof.txt
#
# Fitting method: MCMC
#
# profile1d_type: circ_ap_cube
# moment_calc: False
# partial_weight: True
# pressure_support_type: 1
#
# ###############################
#  Fitting results
# -----------
#  disk+bulge
#     total_mass       10.7580  -   0.0735 +   0.0928
#     r_eff_disk        3.8238  -   0.7459 +   1.1662
#
#     n_disk            1.0000  [FIXED]
#     r_eff_bulge       1.0000  [FIXED]
#     n_bulge           4.0000  [FIXED]
#     bt                0.3000  [FIXED]
# -----------
#  halo
#     fdm               0.3546  -   0.0625 +   0.0647
#
#     mvirial          12.5129  [TIED]
#     conc              5.0000  [FIXED]
# -----------
#  dispprof
#     sigma0           43.4196  -   4.4884 +   4.3869
# -----------
#  zheightgaus
#     sigmaz            0.6495  [TIED]
# -----------
#  geom
#     inc              62.0000  [FIXED]
#     pa              142.0000  [FIXED]
#     xshift            0.0000  [FIXED]
#     yshift            0.0000  [FIXED]
#     vel_shift         0.0000  [FIXED]
#
# -----------
#     mvirial          12.5129  -   0.2757 +   0.0723
#
# -----------
# Adiabatic contraction: False
#
# -----------
# Red. chisq: 2.0668

# %% [markdown]
# ### Or save results report to file:

# %%
# Save report to file:
f_mcmc_report = outdir_mcmc + 'mcmc_fit_report.txt'
mcmc_results.results_report(gal=gal, filename=f_mcmc_report)

# %% [markdown]
# ------
